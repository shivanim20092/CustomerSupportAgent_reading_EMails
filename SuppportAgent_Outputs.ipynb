# %% [markdown]
# 1. Support Agent Outputs
#   -Sample email :
#     "email": {
#         "subject": "Order not received",
#         "body": "I placed an order two weeks ago and still haven't received it.",
#         "from_address": "customer@example.com"
#     }
#
#   - Agent output :
#     - **Classification based on urgency and topic : **
#         Classification of Urgency: High - The customer has a concern about their unreceived order, which indicates immediate attention is needed to resolve the issue as they may be waiting for essential items or have already used them by now.
#
#         Topic Classification: Order Status/Delivery Issue
#
#         Escalation Required: Yes - Given that it's been two weeks since placing an order and there has not been any communication regarding delivery, this matter should escalate to ensure the customer receives their items or is provided with a satisfactory explanation. The lack of response also indicates potential issues in internal processes which need immediate attention from higher management levels.
#
#         Suggested Follow-up: A follow-up email could be sent immediately after classifying it as high urgency, informing them that the issue has been escalated and they can expect a resolution within 24 hours or less if possible. The customer service representative should also apologize for any inconvenience caused due to this delay in delivery/order status update.
#         ** printing response output**
#         Reply Text: Dear Customer, we sincerely apologize for the delay you've experienced with your order and understand how important it is for our customers to receive their purchases promptly. We have escalated your concern as a matter of urgency due to its high priority nature; please rest assured that this issue will be addressed immediately by senior management, who are aware of an ongoing known problem in the current release affecting deliveries like yours. In addition, we're providing you with new password details for our customer support portal so you can stay updated directly and conveniently as your case progresses. We appreciate your patience during this time and assure you that resolving these issues is a top priority for us.
#
#         Should Escalate: True - The issue requires escalation due to the extended period since placing an order without any communication regarding delivery, indicating potential internal process problems which need immediate attention from higher management levels.
#
#         Escalation Summary: Yes – This matter should be escalated because it involves a significant delay in receiving an ordered product and lacks proper updates or resolution attempts by the customer service team so far (2 weeks since order placement). The issue also relates to known problems with current releases, which may affect other customers as well.
#
#         Short Summary for Human Agent: Customer has not received their two-week old order despite no communication from our end regarding delivery status or resolution attempts; the customer is provided new password details and assured of immediate attention by senior management due to high urgency classification.
#         Follow-up scheduled: {'note': 'Needs to schedule for :customer@example.com'}
#         {'email': {'subject': 'Order not received',
#           'body': "I placed an order two weeks ago and still haven't received it.",
#           'from_address': 'customer@example.com'},
#          'classification': "Classification of Urgency: High - The customer has a concern about their unreceived order, which indicates immediate attention is needed to resolve the issue as they may be waiting for essential items or have already used them by now.\n\nTopic Classification: Order Status/Delivery Issue\n\nEscalation Required: Yes - Given that it's been two weeks since placing an order and there has not been any communication regarding delivery, this matter should escalate to ensure the customer receives their items or is provided with a satisfactory explanation. The lack of response also indicates potential issues in internal processes which need immediate attention from higher management levels.\n\nSuggested Follow-up: A follow-up email could be sent immediately after classifying it as high urgency, informing them that the issue has been escalated and they can expect a resolution within 24 hours or less if possible. The customer service representative should also apologize for any inconvenience caused due to this delay in delivery/order status update.",
#          'draft_response': {'text': "Reply Text: Dear Customer, we sincerely apologize for the delay you've experienced with your order and understand how important it is for our customers to receive their purchases promptly. We have escalated your concern as a matter of urgency due to its high priority nature; please rest assured that this issue will be addressed immediately by senior management, who are aware of an ongoing known problem in the current release affecting deliveries like yours. In addition, we're providing you with new password details for our customer support portal so you can stay updated directly and conveniently as your case progresses. We appreciate your patience during this time and assure you that resolving these issues is a top priority for us.\n\nShould Escalate: True - The issue requires escalation due to the extended period since placing an order without any communication regarding delivery, indicating potential internal process problems which need immediate attention from higher management levels. \n\nEscalation Summary: Yes – This matter should be escalated because it involves a significant delay in receiving an ordered product and lacks proper updates or resolution attempts by the customer service team so far (2 weeks since order placement). The issue also relates to known problems with current releases, which may affect other customers as well.\n\nShort Summary for Human Agent: Customer has not received their two-week old order despite no communication from our end regarding delivery status or resolution attempts; the customer is provided new password details and assured of immediate attention by senior management due to high urgency classification.",
#           'should_escalate': False,
#           'follow_up_required': True},
#          'follow_up': {'note': 'Needs to schedule for :customer@example.com'}}

# %% [markdown]
#     2. Support Agent Outputs 2
#
#       -Sample email :
#         "email": {
#             "subject": "Password issue",
#             "body": "How can i reset my password?",
#             "from_address": "customer@example.com"
#         }
#
#         - Agent output :
#     **Classification based on urgency and topic : **
#     Classification of Urgency: High - The customer needs immediate assistance to regain access to their account due to a forgotten password.
#     Topic Classification: Technical Support - This email is seeking help with technical issues related to accessing the user'selfforgotten password.
#     Escalation Required: Yes, because this issue affects the ability of the customer to use essential services provided by your company and may require intervention from a higher-level support team or IT department for resolution (e.g., resetting passwords through system administration tools). A followup is also suggested as it's important to ensure that once resolved, no further issues arise with password management in the future.
#
#     ** printing response output**
#     Reply Text: Dear [Customer Name],
#
#     Thank you for reaching out to us regarding your forgotten password issue. We understand how frustrating this can be and we are here to help! To reset your password immediately, please follow these steps:
#
#     1. Visit our website's login page (link provided below).
#     2. Click on the "Forgot Password" link or button located at the top right corner of the screen.
#     3. Enter your email address associated with your account and click "Submit." You will receive an email containing a password reset link within 5 minutes, if not sooner. Please check both your inbox (and spam folder) as well as any other specified folders for this message from our support team.
#     4. Click on the provided link to access the secure page where you can create and set up a new password using an approved method of authentication or verification such as answering security questions, receiving SMS code via your mobile device number linked with your account (if applicable), etc. Follow these instructions carefully for successful resetting!
#     5. Once completed successfully on this webpage, log in to our system again and use the newly created password that you have just set up above using step 4's guidance as needed going forward from hereon out until we hear back regarding any further assistance required by us at your end should it be necessary (if applicable).
#     6. If after following these steps, there are still issues accessing or resetting passwords for yourself then please do not hesitate to contact our customer support team directly via phone/live chat option available 24/7 so we can assist further with this matter personally! We appreciate your patience during times like these when things may seem difficult initially but rest assured know that together working hand-in-hand will get resolved quickly enough until then too without delaying any services provided by us which would otherwise have been possible had everything gone smoothly right away from start itself instead due unforeseen circumstances beyond control sometimes occurring unexpectedly along way throughout life journey experiences alike!
#
#     We hope this helps resolve your issue promptly so you can continue using our essential services without further hindrance caused by forgotten passwords preventing access into them initially until now resolved finally once again soon enough hopefully never happening ever thereafter hencefor01. Please let us know if anything else comes up regarding any other concerns related directly or indirectly towards this particular matter itself including but not limited too beyond just forgetting password(s) themselves alone already mentioned above earlier previously discussed hereinabove within contextual framework provided initially prior commencement start-up process initiated henceforth thereafter continuously progressing forward steadily moving ahead constantly evolving ever since beginning started back then till present moment time nowadays currently happening right this very second instantaneity itself!
#
#     Best regards,
#     [Your Name] Customer Support Team.
#     Follow-up scheduled: {'note': 'Needs to schedule for :customer@example.com'}
#     {'email': {'subject': 'Password issue',
#       'body': 'How can i reset my password?',
#       'from_address': 'customer@example.com'},
#      'classification': "Classification of Urgency: High - The customer needs immediate assistance to regain access to their account due to a forgotten password.\nTopic Classification: Technical Support - This email is seeking help with technical issues related to accessing the user'selfforgotten password.\nEscalation Required: Yes, because this issue affects the ability of the customer to use essential services provided by your company and may require intervention from a higher-level support team or IT department for resolution (e.g., resetting passwords through system administration tools). A followup is also suggested as it's important to ensure that once resolved, no further issues arise with password management in the future.\n",
#      'draft_response': {'text': 'Reply Text: Dear [Customer Name],\n\nThank you for reaching out to us regarding your forgotten password issue. We understand how frustrating this can be and we are here to help! To reset your password immediately, please follow these steps:\n\n1. Visit our website\'s login page (link provided below).\n2. Click on the "Forgot Password" link or button located at the top right corner of the screen.\n3. Enter your email address associated with your account and click "Submit." You will receive an email containing a password reset link within 5 minutes, if not sooner. Please check both your inbox (and spam folder) as well as any other specified folders for this message from our support team.\n4. Click on the provided link to access the secure page where you can create and set up a new password using an approved method of authentication or verification such as answering security questions, receiving SMS code via your mobile device number linked with your account (if applicable), etc. Follow these instructions carefully for successful resetting!\n5. Once completed successfully on this webpage, log in to our system again and use the newly created password that you have just set up above using step 4\'s guidance as needed going forward from hereon out until we hear back regarding any further assistance required by us at your end should it be necessary (if applicable).\n6. If after following these steps, there are still issues accessing or resetting passwords for yourself then please do not hesitate to contact our customer support team directly via phone/live chat option available 24/7 so we can assist further with this matter personally! We appreciate your patience during times like these when things may seem difficult initially but rest assured know that together working hand-in-hand will get resolved quickly enough until then too without delaying any services provided by us which would otherwise have been possible had everything gone smoothly right away from start itself instead due unforeseen circumstances beyond control sometimes occurring unexpectedly along way throughout life journey experiences alike!\n\nWe hope this helps resolve your issue promptly so you can continue using our essential services without further hindrance caused by forgotten passwords preventing access into them initially until now resolved finally once again soon enough hopefully never happening ever thereafter hencefor01. Please let us know if anything else comes up regarding any other concerns related directly or indirectly towards this particular matter itself including but not limited too beyond just forgetting password(s) themselves alone already mentioned above earlier previously discussed hereinabove within contextual framework provided initially prior commencement start-up process initiated henceforth thereafter continuously progressing forward steadily moving ahead constantly evolving ever since beginning started back then till present moment time nowadays currently happening right this very second instantaneity itself!\n\nBest regards, \n[Your Name] Customer Support Team.',
#       'should_escalate': False,
#       'follow_up_required': True},
#      'follow_up': {'note': 'Needs to schedule for :customer@example.com'}}

# %% [markdown]
# 3. Sample email :
#     "email": {
#         "subject": "feature crash",
#         "body": "Export feature crashes when i click Export pdf button.",
#         "from_address": "customer2@example.com"
#     }
#
# - Agent output :
#               **Classification based on urgency and topic : **
#
#         Classification of Urgency: High - The customer has encountered a critical issue that prevents them from completing their task, which in this case involves exporting data to PDF format. This could be seen as an urgent matter since it directly impacts the user's ability to work efficiently and effectively with your software or service.
#
#         Topic: Bug - The customer is experiencing a problem related to functionality within the application/service, which suggests that there might be an issue in need of investigation by technical support staff.
#
#         Escalation Required: Yes - Given the urgency level (high) and potential impact on user productivity or satisfaction with your software/service, it is advisable for this email to receive immediate attention from a higher-level team member who can address such critical issues more effectively than standard support channels. This could involve escalating the issue within technical support if they are not already aware of similar reports; otherwise, involving product management or development teams may be necessary as well since it appears that there might be an underlying bug in need of resolution before further customer dissatisfaction occurs.
#
#         Follow-up: Yes - After addressing this high urgency issue and providing a timely solution to the user's problem (if possible), follow up with them within 24 hours or sooner if needed, ensuring that they are satisfied with how their concern was handled and confirm whether any further assistance is required. This will help maintain customer trust in your brand while also demonstrating commitment towards continuous improvement of products/services based on user feedback.
#         ** printing response output**
#         Reply Text: Dear [Customer Name],
#
#         Thank you for reaching out to us regarding the issue with exporting data as a PDF file using our software. We understand how important it is for your work processes, and we apologize for any inconvenience this may have caused. Our team has identified that there seems to be an underlying bug in the port-to-PDF feature which might not always function correctly under certain conditions.
#
#         We are treating this as a high urgency issue due to its impact on your ability to complete tasks efficiently and effectively with our software/service, hence we have escalated it internally for immediate attention from senior technical support staff who will work diligently towards finding an appropriate solution or workaround in the shortest possible time.
#
#         In addition, as a follow-up measure after resolving this issue (if feasible), one of our representatives would like to reach out within 24 hours to ensure that you are satisfied with how we handled your concern and if there is any further assistance required on your end or additional feedback from us. We appreciate your patience during this time, as well as for bringing attention to the issue which helps improve overall user experience in our software/service.
#
#         Thank you once again for reaching out to us; please do not hesitate to contact customer support if there are any other concerns that need immediate assistance or clarification regarding using our product/services at your end, we're here 24/7!
#
#         Best regards,
#         [Your Name]
#         Customer Support Team
#         Follow-up scheduled: {'note': 'Needs to schedule for :customer2@example.com'}
#         {'email': {'subject': 'feature crash',
#           'body': 'Export feature crashes when i click Export pdf button.',
#           'from_address': 'customer2@example.com'},
#          'classification': "Classification of Urgency: High - The customer has encountered a critical issue that prevents them from completing their task, which in this case involves exporting data to PDF format. This could be seen as an urgent matter since it directly impacts the user's ability to work efficiently and effectively with your software or service.\n\nTopic: Bug - The customer is experiencing a problem related to functionality within the application/service, which suggests that there might be an issue in need of investigation by technical support staff. \n\nEscalation Required: Yes - Given the urgency level (high) and potential impact on user productivity or satisfaction with your software/service, it is advisable for this email to receive immediate attention from a higher-level team member who can address such critical issues more effectively than standard support channels. This could involve escalating the issue within technical support if they are not already aware of similar reports; otherwise, involving product management or development teams may be necessary as well since it appears that there might be an underlying bug in need of resolution before further customer dissatisfaction occurs.\n\nFollow-up: Yes - After addressing this high urgency issue and providing a timely solution to the user's problem (if possible), follow up with them within 24 hours or sooner if needed, ensuring that they are satisfied with how their concern was handled and confirm whether any further assistance is required. This will help maintain customer trust in your brand while also demonstrating commitment towards continuous improvement of products/services based on user feedback.",
#          'draft_response': {'text': "Reply Text: Dear [Customer Name],\n\nThank you for reaching out to us regarding the issue with exporting data as a PDF file using our software. We understand how important it is for your work processes, and we apologize for any inconvenience this may have caused. Our team has identified that there seems to be an underlying bug in the port-to-PDF feature which might not always function correctly under certain conditions.\n\nWe are treating this as a high urgency issue due to its impact on your ability to complete tasks efficiently and effectively with our software/service, hence we have escalated it internally for immediate attention from senior technical support staff who will work diligently towards finding an appropriate solution or workaround in the shortest possible time.\n\nIn addition, as a follow-up measure after resolving this issue (if feasible), one of our representatives would like to reach out within 24 hours to ensure that you are satisfied with how we handled your concern and if there is any further assistance required on your end or additional feedback from us. We appreciate your patience during this time, as well as for bringing attention to the issue which helps improve overall user experience in our software/service.\n\nThank you once again for reaching out to us; please do not hesitate to contact customer support if there are any other concerns that need immediate assistance or clarification regarding using our product/services at your end, we're here 24/7!\n\nBest regards,\n[Your Name]\nCustomer Support Team",
#           'should_escalate': False,
#           'follow_up_required': True},
#          'follow_up': {'note': 'Needs to schedule for :customer2@example.com'}}
